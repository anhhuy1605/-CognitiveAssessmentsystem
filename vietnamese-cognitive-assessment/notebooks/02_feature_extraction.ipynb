# %%
# Demo: F0 Extraction and Residual (Vietnamese tones)

# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.audio_processing.f0_extraction import extract_f0_raw, extract_f0_residual
import librosa, numpy as np, matplotlib.pyplot as plt

# Use existing sample in project root
audio_path = '../../test_audio.wav'

raw = extract_f0_raw(audio_path)
features = extract_f0_residual(audio_path)
print(features)

plt.figure(figsize=(10,3))
plt.plot(raw['times'], raw['f0'])
plt.title('F0 contour')
plt.xlabel('Time (s)')
plt.ylabel('F0 (Hz)')
plt.tight_layout()
plt.show()
